# %%
from os.path import abspath,dirname,join

file_path:str = join(dirname(abspath(__name__)),'data','peoples.csv')
file_path
# Out:
# '/workspaces/Ron-Phthon/lesson12/data/peoples.csv'

# %%
from csv import DictReader
from pprint import pprint

with open(file_path,encoding='utf-8',newline='') as file:
    reader = DictReader(file)
    pprint(list(reader))
# Out:
# [{'姓名': '溫重意', '身高': '190', '體重': '58'},
#  {'姓名': '黃善迪', '身高': '176', '體重': '78'},
#  {'姓名': '王筱婷', '身高': '180', '體重': '87'},
#  {'姓名': '鄭奇翰', '身高': '186', '體重': '89'},
#  {'姓名': '游治旺', '身高': '181', '體重': '78'},
#  {'姓名': '郭致恬', '身高': '175', '體重': '86'},
#  {'姓名': '白世宏', '身高': '150', '體重': '53'},
#  {'姓名': '鄧哲榮', '身高': '179', '體重': '86'},
#  {'姓名': '黃麗美', '身高': '161', '體重': '86'},
#  {'姓名': '楊又源', '身高': '151', '體重': '67'},
#  {'姓名': '林希啟', '身高': '150', '體重': '78'},
#  {'姓名': '鄭淑珍', '身高': '166', '體重': '61'},
#  {'姓名': '林佳蓉', '身高': '178', '體重': '53'},
#  {'姓名': '臧怡君', '身高': '160', '體重': '81'},
#  {'姓名': '郭舜昇', '身高': '154', '體重': '62'},
#  {'姓名': '賴昌韻', '身高': '160', '體重': '65'},
#  {'姓名': '李佳彥', '身高': '168', '體重': '77'},
#  {'姓名': '林瑞喬', '身高': '179', '體重': '89'},
#  {'姓名': '崔孝憲', '身高': '156', '體重': '79'},
#  {'姓名': '王筱婷', '身高': '183', '體重': '54'},
#  {'姓名': '許芳如', '身高': '182', '體重': '56'},
#  {'姓名': '劉佳佩', '身高': '181', '體重': '65'},
#  {'姓名': '黃詩妃', '身高': '186', '體重': '78'},
#  {'姓名': '孫火清', '身高': '151', '體重': '71'},
#  {'姓名': '錢佩豪', '身高': '185', '體重': '76'},
#  {'姓名': '王怡君', '身高': '151', '體重': '52'},
#  {'姓名': '龔姵君', '身高': '165', '體重': '71'},
#  {'姓名': '林俊翔', '身高': '158', '體重': '90'},
#  {'姓名': '謝佳穎', '身高': '155', '體重': '71'},
#  {'姓名': '黃旻林', '身高': '180', '體重': '73'},
#  {'姓名': '謝水儒', '身高': '160', '體重': '58'},
#  {'姓名': '蔡孟泉', '身高': '150', '體重': '72'},
#  {'姓名': '童建霖', '身高': '176', '體重': '86'},
#  {'姓名': '張凡成', '身高': '156', '體重': '71'},
#  {'姓名': '陳樂紫', '身高': '155', '體重': '77'},
#  {'姓名': '陳彥治', '身高': '172', '體重': '55'},
#  {'姓名': '林思賢', '身高': '172', '體重': '83'},
#  {'姓名': '郭淑枝', '身高': '183', '體重': '71'},
#  {'姓名': '趙家豪', '身高': '190', '體重': '83'},
#  {'姓名': '藍哲嘉', '身高': '184', '體重': '56'},
#  {'姓名': '黃柏宇', '身高': '185', '體重': '89'},
#  {'姓名': '杜儀鳳', '身高': '163', '體重': '77'},
#  {'姓名': '王筱婷', '身高': '189', '體重': '79'},
#  {'姓名': '余丞苓', '身高': '154', '體重': '52'},
#  {'姓名': '吳志宣', '身高': '185', '體重': '86'},
#  {'姓名': '林珍旺', '身高': '160', '體重': '73'},
#  {'姓名': '王惠皓', '身高': '189', '體重': '78'},
#  {'姓名': '謝南慧', '身高': '181', '體重': '89'},
#  {'姓名': '程玫靖', '身高': '152', '體重': '54'},
#  {'姓名': '翁均安', '身高': '153', '體重': '67'}]
