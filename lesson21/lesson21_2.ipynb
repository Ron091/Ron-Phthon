# %%
from dotenv import load_dotenv
import google.generativeai as genai
import os
load_dotenv()
genai.configure(api_key=os.environ['api_key'])
model = genai.GenerativeModel('gemini-1.5-flash')
response = model.generate_content("給我Baldur's gate 3的兼職聖騎士和邪術士的build")
print(response.text)
# Out:
# 好的，以下是《博德之門 3》中兼職聖騎士與邪術士的兩種 build：
#
# **Build 1：神聖復仇者**
#
# * **種族：**人類（額外技能點數）或半精靈（額外技能點數和法術熟練度）
# * **背景：**任何背景都可以，但「軍人」或「貴族」會與聖騎士的角色扮演相得益彰。
# * **主職業：**聖騎士（1-7 級）
# * **副職業：**邪術士（8-12 級）
# * **神祇：**蒂爾（正義之神）或貝倫（守護之神）
# * **子職業：**誓言守護者（聖騎士）和血脈 (邪術士)
#
# **特點：**
#
# * 利用聖騎士的力量和盔甲來做為團隊的坦克，並依靠神聖法術提供治療和控制。
# * 在 8 級時，加入邪術士並取得血脈。選擇「亡靈血脈」或「惡魔血脈」來增強你的傷害輸出和生存能力。
# * 選擇「亡靈血脈」的玩家可以利用「靈魂收割」來回復生命值並對敵人造成傷害。
# * 選擇「惡魔血脈」的玩家可以利用「地獄契約」來提升傷害輸出並賦予自己傷害抗性。
# * 繼續提升聖騎士等級以獲得更多神聖法術和能力，並使用邪術士的攻擊法術來補充你的戰鬥風格。
#
# **技能：**
#
# * 強壯、敏捷、體質
# * 宗教、感知、醫療、欺騙
#
# **裝備：**
#
# * 重型盔甲
# * 一把單手武器和盾牌或雙手武器
#
# **Build 2：黑暗使者**
#
# * **種族：**人類（額外技能點數）或半精靈（額外技能點數和法術熟練度）
# * **背景：**任何背景都可以，但「流浪者」或「陰謀家」會與邪術士的角色扮演相得益彰。
# * **主職業：**邪術士（1-7 級）
# * **副職業：**聖騎士（8-12 級）
# * **神祇：**沙爾（欺騙之神）或洛斯（黑暗之神）
# * **子職業：**血脈 (邪術士) 和誓言守護者（聖騎士）
#
# **特點：**
#
# * 利用邪術士的強大法術和傷害輸出來領導團隊，並依靠聖騎士的力量和盔甲來保護自己。
# * 在 8 級時，加入聖騎士並取得誓言。選擇「誓言守護者」來獲得額外的防禦和治療能力。
# * 利用聖騎士的「神聖之光」法術來治療隊友，並利用邪術士的「魅影」法術來隱藏自己並進行突襲。
# * 繼續提升邪術士等級以獲得更多法術和能力，並使用聖騎士的「聖戰士」能力來增強你的傷害輸出。
#
# **技能：**
#
# * 強壯、敏捷、智力
# * 欺騙、威嚇、感知、宗教
#
# **裝備：**
#
# * 中型盔甲
# * 一把單手武器和盾牌或雙手武器
#
# **注意事項：**
#
# * 這種 build 需要在角色扮演和戰鬥風格之間取得平衡。你必須學會何時使用聖騎士的能力和何時使用邪術士的能力。
# * 你的法術選項會受到聖騎士法術槽的限制，所以必須謹慎選擇你的法術。
# * 你需要專注於你的屬性分配，以確保你能夠有效地使用你的能力。
#
# 希望這些 build 能幫助你建立一個強大的兼職聖騎士與邪術士角色！
